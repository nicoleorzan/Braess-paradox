# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
plt.rcParams['savefig.dpi'] = 50

# %%
df.head()
# Out:
#    delta  Pmax  control[0]  control[1]  control[2]  control[3]  control[4]  \
# 0    4.1   1.1   -0.492511    0.714528    0.774335    0.530559   -0.717260
# 1    4.0   1.1   -0.486523    0.710496    0.770032    0.525033   -0.713260
# 2    3.9   1.1   -0.480372    0.706328    0.765567    0.519354   -0.709125
# 3    3.8   1.1   -0.474053    0.702015    0.760930    0.513515   -0.704845
# 4    3.7   1.1   -0.467557    0.697551    0.756110    0.507509   -0.700414
#
#    control[5]  control[6]  control[7]
# 0   -0.806918    0.714528   -0.717260
# 1   -0.803013    0.710496   -0.713260
# 2   -0.798954    0.706328   -0.709125
# 3   -0.794733    0.702015   -0.704845
# 4   -0.790337    0.697551   -0.700414

# %% [markdown]
# ### Pmax = 0.1

# %%
df = pd.read_csv('Data/control_delta_Pmax_both_varying_doubling_3-4_line', delim_whitespace = True)
df = df[df.delta > 0.2]

df1 = df[df.Pmax == 0.1]
delta1 = df1.loc[:, 'delta']
controls1 = df1.iloc[:, 2:9]
controls1 = -controls1 # I forgot the minus in the printing of data
controls1_abs = controls1.abs()
controls1_sum = controls1_abs.sum(axis=1)

df.head(2)
df.tail()
# Out:
#      delta  Pmax    control[0]    control[1]    control[2]    control[3]  \
# 485    0.7   0.0  1.387779e-16  1.387779e-16  1.387779e-16  1.387779e-16
# 486    0.6   0.0  1.387779e-16  1.387779e-16  1.387779e-16  1.387779e-16
# 487    0.5   0.0  1.387779e-16  1.387779e-16  1.387779e-16  1.387779e-16
# 488    0.4   0.0  1.387779e-16  1.387779e-16  1.387779e-16  1.387779e-16
# 489    0.3   0.0  1.387779e-16  1.387779e-16  1.387779e-16  1.387779e-16
#
#        control[4]    control[5]    control[6]    control[7]
# 485 -1.387779e-16 -1.387779e-16  1.387779e-16 -1.387779e-16
# 486 -1.387779e-16 -1.387779e-16  1.387779e-16 -1.387779e-16
# 487 -1.387779e-16 -1.387779e-16  1.387779e-16 -1.387779e-16
# 488 -1.387779e-16 -1.387779e-16  1.387779e-16 -1.387779e-16
# 489 -1.387779e-16 -1.387779e-16  1.387779e-16 -1.387779e-16

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
ax.plot(delta1, controls1)
ax.set_xlabel('$\delta$', fontsize=20, rotation=0, size = 26)
ax.set_ylabel('$P_{max} tanh( \delta \cdot \Theta_{i} )$', fontsize=18, rotation=90, size = 26)
plt.grid()
plt.savefig('control_vs_delta_Pmax_01_doubling_3-4_line.png', bbox_inches='tight', dpi = 50)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
#ax.plot(delta, controls, markevery=10000)
#ax.plot(delta, controls[0], label = "1")
ax.plot(delta1, controls1[1], label = "2", color='blue')
#ax.plot(delta1, controls1[2], label = "3", color='green')
#ax.plot(delta1, controls1[3], label = "4", color='orange')
#ax.plot(delta1, controls1[4], label = "5", color='black')
#ax.plot(delta1, controls1[5], label = "6", color='red')
#ax.plot(delta1, controls1[6], label = "7", color='fuchsia')
#ax.plot(delta1, controls1[7], label = "8", color='orange')
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
ax.set_xlabel('$\delta$', fontsize=20, rotation=0, size = 26)
ax.set_ylabel('$P_{max} tanh( \delta \cdot \Theta_{i} )$', fontsize=18, rotation=90, size = 26)
plt.grid()
#plt.savefig('control_varying_delta_Pmax_0.1.png', bbox_inches='tight', dpi = 80)
#plt.savefig('control_varying_delta_Pmax_01.png', bbox_inches='tight', dpi = 40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-66b50985a60d> in <module>
#       3 #ax.plot(delta, controls, markevery=10000)
#       4 #ax.plot(delta, controls[0], label = "1")
# ----> 5 ax.plot(delta1, controls1[1], label = "2", color='blue')
#       6 ax.plot(delta1, controls1[2], label = "3", color='green')
#       7 ax.plot(delta1, controls1[3], label = "4", color='orange')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2973             if self.columns.nlevels > 1:
#    2974                 return self._getitem_multilevel(key)
# -> 2975             indexer = self.columns.get_loc(key)
#    2976             if is_integer(indexer):
#    2977                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
# -> 2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2893         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2894         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
ax.plot(delta1, controls1_sum)
ax.set_xlabel('$\delta$', fontsize=20, rotation=0, size = 26)
ax.set_ylabel('$\sum_i | P_{max} tanh( \delta \cdot \Theta_{i} )| $', fontsize=18, rotation=90, size = 26)
plt.grid()
plt.savefig('sum_controls_vs_delta_Pmax_01_doubling_3-4_line.png', bbox_inches='tight', dpi = 50)
plt.show()

# %% [markdown]
# ### Pmax = 0.2

# %%
df2 = df[df.Pmax == 0.2]

delta2 = df2.iloc[:,0]
controls2 = df2.iloc[:, 2:9]
controls2 = -controls2 # I forget the minus in the printing of data
controls2_abs = controls2.abs()
controls2_sum = controls2_abs.sum(axis=1)

df2.head(2)
# Out:
#      delta  Pmax  control[0]  control[1]  control[2]  control[3]  control[4]  \
# 369    4.1   0.2   -0.126433    0.198221    0.197676    0.131010   -0.199494
# 370    4.0   0.2   -0.124401    0.197982    0.197391    0.129498   -0.199401
#
#      control[5]  control[6]  control[7]
# 369   -0.199707    0.198221   -0.199494
# 370   -0.199650    0.197982   -0.199401

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
ax.plot(delta2, controls2)
ax.set_xlabel('$\delta$', fontsize=20, rotation=0, size = 26)
ax.set_ylabel('$P_{max} tanh( \delta \cdot \Theta_{i} )$', fontsize=18, rotation=90, size = 26)
plt.grid()
plt.savefig('control_vs_delta_Pmax_02_doubling_3-4_line.png', bbox_inches='tight', dpi = 50)
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
ax.plot(delta2, controls2_sum)
ax.set_xlabel('$\delta$', fontsize=20, rotation=0, size = 26)
ax.set_ylabel('$\sum_i | P_{max} tanh( \delta \cdot \Theta_{i} )| $', fontsize=18, rotation=90, size = 26)
plt.grid()
plt.savefig('sum_controls_vs_delta_Pmax_02_doubling_3-4_line.png', bbox_inches='tight', dpi = 50)
plt.show()

# %% [markdown]
# ### Surface plot

# %%
delta3 = df.iloc[:,0]
Pmax3 = df.iloc[:,1]
controls3 = df.iloc[:, 2:9]
controls_abs3 = controls3.abs()
controls_sum3 = controls_abs3.sum(axis=1)

# %%
delta3 = np.matrix(delta3)
Pmax3 = np.matrix(Pmax3)
control_sum3 = np.matrix(controls_sum3)
print(delta3.shape)
x = np.reshape(delta3, (492))
print(x.shape)
x = np.reshape(delta3, (123, 4))
print(x.shape)
# Out:
# (1, 492)
# (1, 492)
# (123, 4)

# %%
print(len(delta3))
x = np.reshape(delta3, (4, 123))
y = np.reshape(Pmax3, (4, 123))
z = np.reshape(control_sum3, (4, 123))
# Out:
# 1

# %%
fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(x, y, z)

ax.set_xlabel('$\delta$', fontsize=22, rotation=150, size = 26)
ax.set_ylabel('$Pmax$', fontsize=20, size = 26)
ax.set_zlabel('$\sum_i | P_{max} tanh( \delta \cdot \Theta_{i} )| $', fontsize=20, rotation=60, size = 26)
plt.savefig('surface_doubled.png', bbox_inches='tight', dpi = 50)
plt.show()

# %%
fig = plt.figure(figsize=(14,12))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(x, y, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)

ax.set_xlabel('$\delta$', fontsize=22, rotation=150, size = 26)
ax.set_ylabel('$Pmax$', fontsize=10, size = 26)
ax.set_zlabel('$\sum_i | P_{max} tanh( \delta \cdot \theta_{i} )| $', fontsize=10, rotation=60, size = 26)
plt.show()
