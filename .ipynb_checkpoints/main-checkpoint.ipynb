# %%
# %run define_network.py
# %run network_to_file.py

# %%
create_net = Define_Net(8, 0.3)
create_net.plot_net()
G = create_net.get_network()

net = Network_to_file(G)
#net.PrintOnFile()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-578af8df9275> in <module>
#       3 G = create_net.get_network()
#       4
# ----> 5 net = Network_to_file(G)
#       6 #net.PrintOnFile()
#
# ~/surf/network_to_file.py in __init__(self, Graph, alpha, delta, Pmax, Pvals)
#      14         self.Pmax = Pmax
#      15         self.Pvals = Pvals
# ---> 16         self.createArrays()
#      17         self.Pvals()
#      18
#
# ~/surf/network_to_file.py in createArrays(self)
#      18
#      19     def createArrays(self):
# ---> 20         self.nodes = self.G.number_of_nodes()
#      21         self.AV = [n for i in sorted(self.G.nodes) for n in self.G.neighbors(i)]
#      22         self.connections = len(self.AV)
#
# NameError: name 'G' is not defined
