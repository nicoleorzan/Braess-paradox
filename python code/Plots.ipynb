# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['savefig.dpi'] = 50

# %%
df = pd.read_csv("two_nodes/Data/2nodes_gamma0", delim_whitespace = True)
print(len(df))
df = df.iloc[::6, :]
print(len(df))
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1])
ax.plot(df.iloc[:,0], df.iloc[:,2])
ax.set_xlabel("time(s)", size = 26)
ax.set_ylabel("$\omega (rad.s^{-1})$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.savefig('2nodes_gamma0.png', bbox_inches='tight')
plt.show()
# Out:
# 2000
# 334

# %%
df2 = pd.read_csv("two_nodes/Data/2nodes_gamma0.1", delim_whitespace = True)
fig = plt.figure(figsize=(11, 7))
ax = fig.add_subplot(111)
ax.plot(df2.iloc[:,0], df2.iloc[:,1])
ax.plot(df2.iloc[:,0], df2.iloc[:,2])
ax.set_xlabel("time(s)", size = 26)
ax.set_ylabel("$\omega (rad.s^{-1})$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.savefig('2nodes_gamma01.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/capacity_variation/Data/deltaTheta_vs_capacity_gamma01", delim_whitespace = True)
#df = df.iloc[::6, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "(4,5)", color = 'green')
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "(4,8)", color = 'green')
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "(1,6)", color = 'cyan')
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "(3,4)", color = 'fuchsia')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "(3,2)", color = 'red')
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "(3,7)", color = 'blue')
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "(6,5)", color = 'blue')
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "(6,8)", color = 'red')
ax.plot(df.iloc[:,0], df.iloc[:,9], label = "(2,1)", color = 'black')
ax.plot(df.iloc[:,0], df.iloc[:,10], label = "(7,1)", color = 'black')
ax.set_ylim([-0.05,0.6])
ax.set_xlim([0,1])
ax.set_xlabel("$\Delta K (s^{-2})$", size = 26)
ax.set_ylabel("$\delta \Theta_{ij} / \pi$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.legend(loc = 1, prop={'size': 12})
plt.savefig('Deltatheta_vs_capacity_gamma01.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/capacity_variation/Data/deltaTheta_vs_capacity_gamma0_stopping_where_breaks", delim_whitespace = True)
#df = df.iloc[::6, :]
fig = plt.figure(figsize=(11, 7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "(4,5)", color = 'green')
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "(4,8)", color = 'green')
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "(1,6)", color = 'cyan')
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "(3,4)", color = 'fuchsia')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "(3,2)", color = 'red')
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "(3,7)", color = 'blue')
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "(6,5)", color = 'blue')
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "(6,8)", color = 'red')
ax.plot(df.iloc[:,0], df.iloc[:,9], label = "(2,1)", color = 'black')
ax.plot(df.iloc[:,0], df.iloc[:,10], label = "(7,1)", color = 'black')
ax.set_ylim([-0.05,0.6])
ax.set_xlim([0,1])
ax.set_xlabel("$\Delta K (s^{-2})$", size = 26)
ax.set_ylabel("$\delta \Theta_{ij} / \pi$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.legend(loc = 1, prop={'size': 12})
plt.savefig('Deltatheta_vs_capacity_gamma0.png', bbox_inches='tight')
plt.show()

# %%
df1 = pd.read_csv("more_nodes/Data/original_network_gamma0", delim_whitespace = True)
df2 = pd.read_csv("more_nodes/Data/doubled_3-4_gamma0", delim_whitespace = True)
df3 = pd.read_csv("more_nodes/Data/adding_line_gamma0", delim_whitespace = True)
df4 = pd.read_csv("more_nodes/Data/original_network_gamma0.1", delim_whitespace = True)
df5 = pd.read_csv("more_nodes/Data/doubled_3-4_gamma0.1", delim_whitespace = True)
df6 = pd.read_csv("more_nodes/Data/adding_line_gamma0.1", delim_whitespace = True)
df1 = df1.iloc[::6, :]
df2 = df2.iloc[::6, :]
df3 = df3.iloc[::6, :]
df4 = df4.iloc[::6, :]
df5 = df5.iloc[::6, :]
df6 = df6.iloc[::6, :]

fig, axs = plt.subplots(2,3, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0}, figsize=(20, 10))
(ax1, ax2, ax3), (ax4, ax5, ax6)= axs

fig.suptitle('')
ax1.plot(df1.iloc[:,0], df1.iloc[:,1:8]/3.14, label = "1")
ax1.set_ylim([-2,2])
ax1.set_xlabel("time (s)", size = 20)
ax1.set_ylabel("Uncontrolled \n$\Theta_{ij} / \pi$", size = 20)
ax1.set_title("Original configuration", size = 19)
ax1.text(0,1.6,"a)", size = 19)
ax1.grid()

ax2.plot(df2.iloc[:,0], df2.iloc[:,1:8]/3.14, label = "1")
ax2.set_ylim([-2,2])
ax2.set_xlabel("time (s)", size = 20)
ax2.set_ylabel("$\Theta_{ij} / \pi$", size = 20)
ax2.set_title("Increasing 3-4 capacity", size = 19)
ax2.text(0,1.6,"b)", size = 19)
ax2.grid()

ax3.plot(df3.iloc[:,0], df3.iloc[:,1:8]/3.14, label = "1")
ax3.set_ylim([-2,2])
ax3.set_xlabel("time (s)", size = 20)
ax3.set_ylabel("$\Theta_{ij} / \pi$", size = 20)
ax3.set_title("Adding 2-4 line", size = 19)
ax3.text(0,1.6,"c)", size = 19)
ax3.grid()

ax4.plot(df4.iloc[:,0], df4.iloc[:,1:8]/3.14, label = "1")
ax4.set_ylim([-2,2])
ax4.set_xlabel("time (s)", size = 20)
ax4.set_ylabel("Controlled \n $\Theta_{ij} / \pi$", size = 20)
ax4.text(0,1.6,"d)", size = 19)
ax4.grid()

ax5.plot(df5.iloc[:,0], df5.iloc[:,1:8]/3.14, label = "1")
ax5.set_ylim([-2,2])
ax5.set_xlabel("time (s)", size = 20)
ax5.set_ylabel("$\Theta_{ij} / \pi$", size = 20)
ax5.text(0,1.6,"e)", size = 19)
ax5.grid()

ax6.plot(df6.iloc[:,0], df6.iloc[:,1:8]/3.14, label = "1")
ax6.set_ylim([-2,2])
ax6.set_xlabel("time (s)", size = 20)
ax6.set_ylabel("$\Theta_{ij} / \pi$", size = 20)
ax6.text(0,1.6,"f)", size = 19)
ax6.grid()
#ax2.plot(x, y**2, 'tab:orange')
#ax3.plot(x + 1, -y, 'tab:green')
#ax4.plot(x + 2, -y**2, 'tab:red')

for ax in axs.flat:
    ax.label_outer()
    
plt.savefig('alltogheter.png', bbox_inches='tight')

# %%
df = pd.read_csv("more_nodes/Data/control_vs_capacity_variation_on_3-4_Pmax02", delim_whitespace = True)
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_xlim([0,1])
ax.set_title("$P_{max} = 0.2$,   $\delta = 0.1/P_{max}$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('control_vs_capacity_variation_on_3-4_Pmax02.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/control_vs_capacity_variation_on_3-4_Pmax01", delim_whitespace = True)
#df = df.iloc[::6, :]

fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_xlim([0,1.0])
ax.set_title("$P_{max} = 0.1$,   $\delta = 0.1/P_{max}$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('control_vs_capacity_variation_on_3-4_Pmax01.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/control_vs_capacity_variation_on_3-4_Pmax002", delim_whitespace = True)
df = df.iloc[::2, :]


fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_xlim([0,1])
ax.set_title("$P_{max} = 0.02$,   $\delta = 0.1/P_{max}$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('control_vs_capacity_variation_on_3-4_Pmax002.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/control_vs_capacity_variation_on_3-4_Pmax001", delim_whitespace = True)
#df = df.iloc[::6, :]

fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_xlim([0,1])
ax.set_title("$P_{max} = 0.01$,   $\delta = 0.1/P_{max}$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('original_newtork_control_vs_capacity_variation_on_3-4_Pmax001.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/phases_vs_pmax_with_delta_01_over_pmax_original_network", delim_whitespace = True)
df = df.iloc[::2, :]

fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("Original network, $\delta = 0.1/P_{max}$", size=26)
ax.set_xlabel("$P_{max}$", size = 26)
ax.set_ylabel("$\Theta_i$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,0.2])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('phases_vs_pmax_with_delta_01_over_pmax_original_network.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/phases_vs_pmax_with_delta_01_over_pmax_doubled_3-4_line", delim_whitespace = True)
df = df.iloc[::2, :]

fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("Doubled 3-4 line, $\delta = 0.1/P_{max}$", size=26)
ax.set_xlabel("$P_{max}$", size = 26)
ax.set_ylabel("$\Theta_i$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,0.2])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('phases_vs_pmax_with_delta_01_over_pmax_doubled_3-4_line.png', bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/delta1_pmax02_capacity_variation", delim_whitespace = True)
df = df.iloc[::2, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max} = 0.2$,   $\delta = 1$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,1])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('delta1_pmax02_capacity_variation.png', bbox_inches='tight', dpi=80)
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/delta1_pmax01_capacity_variation", delim_whitespace = True)
df = df.iloc[::2, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max} = 0.1$,   $\delta = 1$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,1])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('delta1_pmax01_capacity_variation.png', bbox_inches='tight', dpi=80)
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/delta1_pmax002_capacity_variation", delim_whitespace = True)
df = df.iloc[::2, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max} = 0.02$,   $\delta = 1$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,1])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('delta1_pmax002_capacity_variation.png', bbox_inches='tight', dpi=80)
plt.show()

# %%
df = pd.read_csv("more_nodes/Data/delta1_pmax001_capacity_variation", delim_whitespace = True)
df = df.iloc[::2, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max} = 0.01$,   $\delta = 1$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,1])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('delta1_pmax001_capacity_variation.png', bbox_inches='tight', dpi=80)
plt.show()

# %%
df = pd.read_csv("more_nodes/Pmaxs_generators_consumers/Plots_and_data/control_function_of_deltaK_Pmax_generators_0.1_consumers_0.01", delim_whitespace = True)
#df = df.iloc[::2, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max}gen = 0.1$,   $P_{max}cons = 0.01$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,0.69])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('control_function_of_deltaK_Pmax_generators_01_consumers_001.png', bbox_inches='tight', dpi=80)
plt.show()

# %%
df = pd.read_csv("more_nodes/Pmaxs_generators_consumers/Plots_and_data/deltaTheta_function_deltaK_Pmax_generators_0.1_consumers_0.01", delim_whitespace = True)
#df = df.iloc[::4, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max}gen = 0.1$   $P_{max}cons = 0.01$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("$\Theta_i$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,0.69])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('deltaTheta_function_deltaK_Pmax_generators_01_consumers_001.png', bbox_inches='tight', dpi=80)
plt.show()

# %%
df = pd.read_csv("more_nodes/Pmaxs_generators_consumers/Plots_and_data/control_function_of_deltaK_Pmax_generators_01_consumers_0001", delim_whitespace = True)
df = df.iloc[::4, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max}gen = 0.1$,   $P_{max}cons = 0.001$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("-$P_{max} \cdot tanh(\delta \cdot \Theta_i)$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,0.7])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('control_function_of_deltaK_Pmax_generators_01_consumers_0001.png', bbox_inches='tight', dpi=80)
plt.show()

# %%
df = pd.read_csv("more_nodes/Pmaxs_generators_consumers/Plots_and_data/deltaTheta_function_deltaK_Pmax_generators_0.1_consumers_0.001", delim_whitespace = True)
df = df.iloc[::4, :]
fig = plt.figure(figsize=(11,7))
ax = fig.add_subplot(111)
ax.plot(df.iloc[:,0], df.iloc[:,1], label = "1")
ax.plot(df.iloc[:,0], df.iloc[:,2], label = "2")
ax.plot(df.iloc[:,0], df.iloc[:,3], label = "3")
ax.plot(df.iloc[:,0], df.iloc[:,4], label = "4")#, color='red')
ax.plot(df.iloc[:,0], df.iloc[:,5], label = "5")
ax.plot(df.iloc[:,0], df.iloc[:,6], label = "6")
ax.plot(df.iloc[:,0], df.iloc[:,7], label = "7")
ax.plot(df.iloc[:,0], df.iloc[:,8], label = "8")
ax.set_title("$P_{max}gen = 0.1$   $P_{max}cons = 0.001$", size=26)
ax.set_xlabel("$\Delta K$ $(s^{-2})$", size = 26)
ax.set_ylabel("$\Theta_i$", size = 26)
ax.tick_params(labelsize=21)
ax.set_xlim([0,0.69])
plt.grid()
plt.legend(loc='upper right', prop={'size': 15}, framealpha=0.6)
plt.savefig('deltaTheta_function_deltaK_Pmax_generators_01_consumers_0001.png', bbox_inches='tight', dpi=80)
plt.show()
