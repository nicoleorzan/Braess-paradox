# %%
# %run define_network.py
# %run network_to_file.py

# %%
create_net = Define_Net(8, 0.4, w = 10)
create_net.plot_net()
G = create_net.get_network()

net = Network_to_file(G, create_net.Pvals)
net.PrintOnFile()
